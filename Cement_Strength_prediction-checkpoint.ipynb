# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data = pd.read_csv('concrete_data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cement            1030 non-null   float64
#  1   slag              1030 non-null   float64
#  2   flyash            1030 non-null   float64
#  3   water             1030 non-null   float64
#  4   superplasticizer  1030 non-null   float64
#  5   coarseaggregate   1030 non-null   float64
#  6   fineaggregate     1030 non-null   float64
#  7   age               1030 non-null   int64
#  8   csMPa             1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
data.describe()
# Out:
#             cement         slag       flyash        water  superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        coarseaggregate  fineaggregate          age        csMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# min         801.000000     594.000000     1.000000     2.330000
# 25%         932.000000     730.950000     7.000000    23.710000
# 50%         968.000000     779.500000    28.000000    34.445000
# 75%        1029.400000     824.000000    56.000000    46.135000
# max        1145.000000     992.600000   365.000000    82.600000

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.isnull().sum()
# Out:
# cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64

# %%
data.corr()
# Out:
#                     cement      slag    flyash     water  superplasticizer  \
# cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# slag             -0.275216  1.000000 -0.323580  0.107252          0.043270
# flyash           -0.397467 -0.323580  1.000000 -0.256984          0.377503
# water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# superplasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# coarseaggregate  -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# fineaggregate    -0.222718 -0.281603  0.079108 -0.450661          0.222691
# age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# csMPa             0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                   coarseaggregate  fineaggregate       age     csMPa
# cement                  -0.109349      -0.222718  0.081946  0.497832
# slag                    -0.283999      -0.281603 -0.044246  0.134829
# flyash                  -0.009961       0.079108 -0.154371 -0.105755
# water                   -0.182294      -0.450661  0.277618 -0.289633
# superplasticizer        -0.265999       0.222691 -0.192700  0.366079
# coarseaggregate          1.000000      -0.178481 -0.003016 -0.164935
# fineaggregate           -0.178481       1.000000 -0.156095 -0.167241
# age                     -0.003016      -0.156095  1.000000  0.328873
# csMPa                   -0.164935      -0.167241  0.328873  1.000000

# %%
plt.figure(figsize=(8,4))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['cement', 'slag', 'flyash', 'water', 'superplasticizer',
#        'coarseaggregate', 'fineaggregate', 'age', 'csMPa'],
#       dtype='object')

# %%
fig=sns.pairplot(data,height=2.0, aspect=1.8, 
                plot_kws={'edgecolor': 'k', 'linewidth': 1.0},
                diag_kind='kde', diag_kws={'shade': True})

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber=1
for column in data.columns:
    plt.subplot(3,3,plotnumber)
    sns.distplot(data[column])
    plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = data.drop('concrete_compressive_strength', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2700601756.py in <module>
#       1 plt.figure(figsize=(10,6),facecolor='white')
# ----> 2 sns.heatmap(x.corr(), annot=True)
#
# NameError: name 'x' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/32546335.py in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
y = data['concrete_compressive_strength']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'concrete_compressive_strength'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/1430375627.py in <module>
# ----> 1 y = data['concrete_compressive_strength']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'concrete_compressive_strength'

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3563912222.py in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
for column in x.columns:
    x[column]+=1
    x[column]= np.log(x[column])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3042082320.py in <module>
# ----> 1 for column in x.columns:
#       2     x[column]+=1
#       3     x[column]= np.log(x[column])
#
# NameError: name 'x' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/32546335.py in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber = 1
for column in x.columns:
    plt.subplot(3,3,plotnumber)
    sns.distplot(x[column])
    plt.xlabel(column, fontsize=13)
    plotnumber+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3429821337.py in <module>
#       1 plt.figure(figsize=(12,12),facecolor='white')
#       2 plotnumber = 1
# ----> 3 for column in x.columns:
#       4     plt.subplot(3,3,plotnumber)
#       5     sns.distplot(x[column])
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber=1
for column in x.columns:
    plt.subplot(3,3,plotnumber)
    sns.boxplot(x[column])
    plt.xlabel(column)
    plotnumber+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2378168451.py in <module>
#       1 plt.figure(figsize=(12,12),facecolor='white')
#       2 plotnumber=1
# ----> 3 for column in x.columns:
#       4     plt.subplot(3,3,plotnumber)
#       5     sns.boxplot(x[column])
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber=1
for column in x.columns:
    plt.subplot(3,3,plotnumber)
    sns.scatterplot(x[column],y)
    plt.xlabel(column)
    plotnumber+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/4064396162.py in <module>
#       1 plt.figure(figsize=(12,12),facecolor='white')
#       2 plotnumber=1
# ----> 3 for column in x.columns:
#       4     plt.subplot(3,3,plotnumber)
#       5     sns.scatterplot(x[column],y)
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(10,6),facecolor='white')
sns.heatmap(x.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2700601756.py in <module>
#       1 plt.figure(figsize=(10,6),facecolor='white')
# ----> 2 sns.heatmap(x.corr(), annot=True)
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(10,6),facecolor='white')
sns.heatmap(x.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2700601756.py in <module>
#       1 plt.figure(figsize=(10,6),facecolor='white')
# ----> 2 sns.heatmap(x.corr(), annot=True)
#
# NameError: name 'x' is not defined

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/1710797709.py in <module>
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
x_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/1829659475.py in <module>
# ----> 1 x_test
#
# NameError: name 'x_test' is not defined

# %%
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2642340758.py in <module>
# ----> 1 y_train
#
# NameError: name 'y_train' is not defined

# %%
y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/4075987148.py in <module>
# ----> 1 y_test
#
# NameError: name 'y_test' is not defined

# %%
scalar = StandardScaler()

# %%
X_train = scalar.fit(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3825240432.py in <module>
# ----> 1 X_train = scalar.fit(x_train)
#
# NameError: name 'x_train' is not defined

# %%
X_train = scalar.transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/1941993955.py in <module>
# ----> 1 X_train = scalar.transform(x_train)
#
# NameError: name 'x_train' is not defined

# %%
X_test = scalar.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2205002054.py in <module>
# ----> 1 X_test = scalar.transform(x_test)
#
# NameError: name 'x_test' is not defined

# %%
X_train= pd.DataFrame(X_train,columns=x_train.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2254111129.py in <module>
# ----> 1 X_train= pd.DataFrame(X_train,columns=x_train.columns)
#
# NameError: name 'X_train' is not defined

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/4239342174.py in <module>
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
X_test= pd.DataFrame(X_test,columns=x_test.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/478041505.py in <module>
# ----> 1 X_test= pd.DataFrame(X_test,columns=x_test.columns)
#
# NameError: name 'X_test' is not defined

# %%
X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2302220135.py in <module>
# ----> 1 X_test
#
# NameError: name 'X_test' is not defined

# %%
print(X_train.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/1693775889.py in <module>
# ----> 1 print(X_train.mean())
#
# NameError: name 'X_train' is not defined

# %%
print(X_train.var())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/948627768.py in <module>
# ----> 1 print(X_train.var())
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR, LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor

# %%
models = {
    "                     Linear Regression" : LinearRegression(),
    "                 L2 (Ridge) Regression" : Ridge(),
    "Support Vector Machine (Linear Kernel)" : LinearSVR(),
    "   Support Vector Machine (RBF Kernel)" : SVR(),
    "                         Decision Tree" : DecisionTreeRegressor(),
    "                        Neural Network" : MLPRegressor(),
    "                         Random Forest" : RandomForestRegressor(),
    "                     Gradient Boosting" : GradientBoostingRegressor(),
    "                              AdaBoost" : AdaBoostRegressor()
}

# %%
for name,model in models.items():
    model.fit(X_train,y_train)
    print('model trained with. {}'.format(name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/2966152877.py in <module>
#       1 for name,model in models.items():
# ----> 2     model.fit(X_train,y_train)
#       3     print('model trained with. {}'.format(name))
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.metrics import r2_score

# %%
for name, model in models.items():
    y_pred = model.predict(X_test)
    score = r2_score(y_test,y_pred)
    print(score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3999375590.py in <module>
#       1 for name, model in models.items():
# ----> 2     y_pred = model.predict(X_test)
#       3     score = r2_score(y_test,y_pred)
#       4     print(score)
#
# NameError: name 'X_test' is not defined

# %%
best_model = GradientBoostingRegressor()
best_model.fit(X_train,y_train)
y_pred = best_model.predict(X_test)
score = r2_score(y_test,y_pred)
print ('score before hyperparameter tuning {}'.format(score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3152629225.py in <module>
#       1 best_model = GradientBoostingRegressor()
# ----> 2 best_model.fit(X_train,y_train)
#       3 y_pred = best_model.predict(X_test)
#       4 score = r2_score(y_test,y_pred)
#       5 print ('score before hyperparameter tuning {}'.format(score))
#
# NameError: name 'X_train' is not defined

# %%
param = {
    'learning_rate' : [0.01, 0.1, 1.0],
    'n_estimators' : [100, 150, 200],
    'max_depth' : [3, 4, 5]
}

# %%
clf = GridSearchCV(estimator=best_model,param_grid=param)
clf.fit(X_train,y_train)
#best_accuracy = clf.best_score_
best_param = clf.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/646911946.py in <module>
#       1 clf = GridSearchCV(estimator=best_model,param_grid=param)
# ----> 2 clf.fit(X_train,y_train)
#       3 #best_accuracy = clf.best_score_
#       4 best_param = clf.best_params_
#
# NameError: name 'X_train' is not defined

# %%
#print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print(best_param)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/3133438190.py in <module>
#       1 #print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
# ----> 2 print(best_param)
#
# NameError: name 'best_param' is not defined

# %%
y_pred = clf.predict(X_test)
score = r2_score(y_test,y_pred)
print ('score after hyperparameter tuning {}'.format(score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1664/1176419525.py in <module>
# ----> 1 y_pred = clf.predict(X_test)
#       2 score = r2_score(y_test,y_pred)
#       3 print ('score after hyperparameter tuning {}'.format(score))
#
# NameError: name 'X_test' is not defined
